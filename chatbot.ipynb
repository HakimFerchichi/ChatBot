# %% [markdown]
# Python modules and libraries to code our robot, we're going to need a few modules built into Python, as well as some popular libraries for NLP and Deep Learning, as well as the de facto NumPy library, which is ideal for processing arrays.

# %%
import json
import string
import random 
import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer 
import tensorflow as tf 
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense, Dropout
nltk.download("punkt")
nltk.download("wordnet")
nltk.download('omw-1.4')
# Out:
# 2022-07-04 15:09:30.945771: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-07-04 15:09:30.949703: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-07-04 15:09:30.949723: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# [nltk_data] Downloading package punkt to /home/hakim/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/hakim/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# Data:
# Before we start thinking about coding a few lines in Python, we need to set up a JSON intents file that defines some of the intents that might occur during interactions with our chatbot. To do this, we first need to create a set of tags into which user requests can fit.
# For example:
#
# A user may want to know the first name of our chatbot, so we create an intent tagged with a tag called name.
# A user may want to know the age of our chatbot, so we create an intent tagged with the age tag and so on...
#
# Tags and Patterns:
# For each of the tags we create, we need to specify patterns. This defines the different ways a user can ask a question to our chatbot. For example, under the name tag, a user can ask a person's first name in different ways: "What is your first name?", "Who are you?", "What is your name?".
#
# The chatbot then takes these patterns and uses them as training data to determine what a person asking our chatbot for their first name would look like. The goal is for it to be able to adapt to the different ways a person might ask our chatbot for their first name. Therefore, users don't need to use the exact queries that our chatbot has learned. They could ask the question "What's your name?" and our chatbot would be able to deduce that the user wants to know their first name and in response it would then provide their first name.
#
# Remark:
# Our robot won't be super intelligent and therefore it won't always recognize what is said or asked. But with enough examples, it will be able to do a more than interesting job of deciphering. Keep in mind that our goal is mainly to implement NLP and Deep Learning techniques. And thus build our chatbot with these 2 elements under the hood.
#
# Responses associated to the Patterns:
# In this JSON intents file containing our various intents, next to each intents tag and pattern, there will be pre-recorded responses. Indeed, for our chatbot (which I repeat will be very simple and naive), these answers will not be generated. This means that our patterns will not be as fluid as the patterns that users may ask for (i.e. they will not adapt to the situation and the context).
# What does this mean? Well, simply that the answers will be static answers that the chatbot will return when asked a question

# %%
# use of a dictionary to represent a JSON file of intentions
data = {"intents": [
             {"tag": "greeting",
              "patterns": ["Hello", "La forme?", "yo", "Salut", "ça roule?"],
              "responses": ["Salut à toi!", "Hello", "Comment vas tu?", "Salutations!", "Enchanté"],
             },
             {"tag": "age",
              "patterns": ["Quel âge as-tu?", "C'est quand ton anniversaire?", "Quand es-tu né?"],
              "responses": ["J'ai 25 ans", "Je suis né en 1996", "Ma date d'anniversaire est le 3 juillet et je suis né en 1996", "03/07/1996"]
             },
             {"tag": "date",
              "patterns": ["Que fais-tu ce week-end?",
"Tu veux qu'on fasse un truc ensemble?", "Quels sont tes plans pour cette semaine"],
              "responses": ["Je suis libre toute la semaine", "Je n'ai rien de prévu", "Je ne suis pas occupé"]
             },
             {"tag": "name",
              "patterns": ["Quel est ton prénom?", "Comment tu t'appelles?", "Qui es-tu?"],
              "responses": ["Mon prénom est Miki", "Je suis Miki", "Miki"]
             },
             {"tag": "goodbye",
              "patterns": [ "bye", "Salut", "see ya", "adios", "cya"],
              "responses": ["C'était sympa de te parler", "à plus tard", "On se reparle très vite!"]
             }
]}

# %% [markdown]
# Séparation des données
# Afin de créer nos données d’entraînement, nous devons d’abord effectuer certaines opérations sur nos données telles que :
#
# Créer un vocabulaire de tous les mots utilisés dans les patterns (rappelons que les patterns sont les requêtes/questions posées par l’utilisateur).
# Créer une liste des classes – Il s’agit simplement des tags de chaque intention.
# Créer une liste de tous les patterns dans le fichier des intentions.
# Créer une liste de touts les tags associés à chaque pattern dans le fichier intents.

# %%
# initialization of lemmatizer to get the root of the mots
lemmatizer = WordNetLemmatizer()
# listes creation
words = []
classes = []
doc_X = []
doc_y = []
# browse with a For loop all the intentions
# tokenize each pattern and add the tokens to the words list, the patterns and
# the tag associated to the intention are added to the corresponding lists
for intent in data["intents"]:
    for pattern in intent["patterns"]:
        tokens = nltk.word_tokenize(pattern)
        words.extend(tokens)
        doc_X.append(pattern)
        doc_y.append(intent["tag"])
    
    # add the tag to the classes if it is not already there 
    if intent["tag"] not in classes:
        classes.append(intent["tag"])
# lemmatize all vocabulary words and convert them to lower case
# if the words do not appear in the punctuation
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
# sort the vocabulary and classes alphabetically and take the
# set to make sure there are no duplicates
words = sorted(set(words))
classes = sorted(set(classes))

# %% [markdown]
# Voici à quoi ressemble chaque liste :

# %%
print(words)
print(classes)
print(doc_X)
print(doc_y)
# Out:
# ['adios', 'anniversaire', 'as-tu', 'bye', "c'est", 'ce', 'cette', 'comment', 'cya', 'ensemble', 'es-tu', 'est', 'fais-tu', 'fasse', 'forme', 'hello', 'la', 'né', 'plan', 'pour', 'prénom', "qu'on", 'quand', 'que', 'quel', 'quels', 'qui', 'roule', 'salut', 'see', 'semaine', 'sont', "t'appelles", 'te', 'ton', 'truc', 'tu', 'un', 'veux', 'week-end', 'ya', 'yo', 'âge', 'ça']
# ['age', 'date', 'goodbye', 'greeting', 'name']
# ['Hello', 'La forme?', 'yo', 'Salut', 'ça roule?', 'Quel âge as-tu?', "C'est quand ton anniversaire?", 'Quand es-tu né?', 'Que fais-tu ce week-end?', "Tu veux qu'on fasse un truc ensemble?", 'Quels sont tes plans pour cette semaine', 'Quel est ton prénom?', "Comment tu t'appelles?", 'Qui es-tu?', 'bye', 'Salut', 'see ya', 'adios', 'cya']
# ['greeting', 'greeting', 'greeting', 'greeting', 'greeting', 'age', 'age', 'age', 'date', 'date', 'date', 'name', 'name', 'name', 'goodbye', 'goodbye', 'goodbye', 'goodbye', 'goodbye']

# %% [markdown]
# Data Processing:
#
# Now that we have separated our data, we are ready to train our algorithm. However, neural networks expect to receive numerical values, not words. So we must first process our data so that a neural network can read what we are doing.
#
# In order to convert our data into numerical values, we will use a "bag of words" technique.

# %%
# liste for trainig data
training = []
out_empty = [0] * len(classes)
# creation of the word set model
for idx, doc in enumerate(doc_X):
    bow = []
    text = lemmatizer.lemmatize(doc.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)
    # marks the index of the class to which the atguel pattern is associated with
    output_row = list(out_empty)
    output_row[classes.index(doc_y[idx])] = 1
    # adds the one hot encoded BoW and associated classes to the training list
    training.append([bow, output_row])
# mix the data and convert them into an array
random.shuffle(training)
training = np.array(training, dtype=object)
# separate features and target labels
train_X = np.array(list(training[:, 0]))
train_y = np.array(list(training[:, 1]))
# Out:
# [nltk_data] Downloading package omw-1.4 to /home/hakim/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# Building the Deep Learning neural network:
#
# After converting our data to digital format, we can now build a neural network model into which we will feed our training data. The idea is that the model examines the features and predicts the label associated with those features, and then selects an appropriate response from that label.

# %%
# definition of some parameters
input_shape = (len(train_X[0]),)
output_shape = len(train_y[0])
epochs = 200

# %%
#Model
model = Sequential()
model.add(Dense(128, input_shape=input_shape, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(output_shape, activation = "softmax"))
adam = tf.keras.optimizers.Adam(learning_rate=0.01, decay=1e-6)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=["accuracy"])
# Out:
# 2022-07-04 15:25:22.913560: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-04 15:25:22.913586: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (hakim-Vostro-3500): /proc/driver/nvidia/version does not exist
# 2022-07-04 15:25:22.913887: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               5760
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 14,341
# Trainable params: 14,341
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# In our sequential model, we used exclusion layers (or DropOut) which are very effective in preventing Deep Learning models from over-fitting the data.

# %%
# entraînement du modèle
model.fit(x=train_X, y=train_y, epochs=200, verbose=1)
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 394ms/step - loss: 1.6594 - accuracy: 0.2632
# Epoch 2/200
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5506 - accuracy: 0.3684
# Epoch 3/200
# 1/1 [==============================] - 0s 4ms/step - loss: 1.3862 - accuracy: 0.5263
# Epoch 4/200
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2301 - accuracy: 0.7368
# Epoch 5/200
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1377 - accuracy: 0.8947
# Epoch 6/200
# 1/1 [==============================] - 0s 5ms/step - loss: 1.0305 - accuracy: 0.6842
# Epoch 7/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8992 - accuracy: 0.7895
# Epoch 8/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.8762 - accuracy: 0.7895
# Epoch 9/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.8010 - accuracy: 0.8421
# Epoch 10/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5641 - accuracy: 0.8947
# Epoch 11/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4455 - accuracy: 0.9474
# Epoch 12/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4488 - accuracy: 0.8947
# Epoch 13/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3250 - accuracy: 0.8947
# Epoch 14/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2936 - accuracy: 0.8947
# Epoch 15/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2337 - accuracy: 1.0000
# Epoch 16/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2192 - accuracy: 0.9474
# Epoch 17/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1253 - accuracy: 1.0000
# Epoch 18/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2286 - accuracy: 0.9474
# Epoch 19/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1867 - accuracy: 0.9474
# Epoch 20/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0641 - accuracy: 1.0000
# Epoch 21/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.2285 - accuracy: 0.9474
# Epoch 22/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1570 - accuracy: 0.9474
# Epoch 23/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3054 - accuracy: 0.8421
# Epoch 24/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0940 - accuracy: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1937 - accuracy: 0.8947
# Epoch 26/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1288 - accuracy: 0.8947
# Epoch 27/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1711 - accuracy: 0.9474
# Epoch 28/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1480 - accuracy: 0.8947
# Epoch 29/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1085 - accuracy: 0.9474
# Epoch 30/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0612 - accuracy: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2066 - accuracy: 0.8947
# Epoch 32/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1515 - accuracy: 0.8947
# Epoch 33/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0536 - accuracy: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0345 - accuracy: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1541 - accuracy: 0.8947
# Epoch 36/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2274 - accuracy: 0.9474
# Epoch 37/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1515 - accuracy: 0.9474
# Epoch 38/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0614 - accuracy: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0818 - accuracy: 0.9474
# Epoch 40/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0625 - accuracy: 0.9474
# Epoch 41/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1298 - accuracy: 0.9474
# Epoch 42/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1555 - accuracy: 0.9474
# Epoch 43/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1951 - accuracy: 0.9474
# Epoch 44/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0666 - accuracy: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1168 - accuracy: 0.9474
# Epoch 46/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1525 - accuracy: 0.8947
# Epoch 47/200
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0891 - accuracy: 0.9474
# Epoch 48/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0605 - accuracy: 0.9474
# Epoch 49/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1421 - accuracy: 0.9474
# Epoch 50/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0554 - accuracy: 0.9474
# Epoch 51/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1094 - accuracy: 0.8947
# Epoch 52/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0515 - accuracy: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0700 - accuracy: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1320 - accuracy: 0.8947
# Epoch 55/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2607 - accuracy: 0.8947
# Epoch 56/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2561 - accuracy: 0.8947
# Epoch 57/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1336 - accuracy: 0.8947
# Epoch 58/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2618 - accuracy: 0.8947
# Epoch 59/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1934 - accuracy: 0.8947
# Epoch 60/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0964 - accuracy: 0.9474
# Epoch 61/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1106 - accuracy: 0.8947
# Epoch 62/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0634 - accuracy: 0.9474
# Epoch 63/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0596 - accuracy: 0.9474
# Epoch 64/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0639 - accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1240 - accuracy: 0.8947
# Epoch 66/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1478 - accuracy: 0.8947
# Epoch 67/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1890 - accuracy: 0.8947
# Epoch 68/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1028 - accuracy: 0.8947
# Epoch 69/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0949 - accuracy: 0.9474
# Epoch 70/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0556 - accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0740 - accuracy: 0.9474
# Epoch 72/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0655 - accuracy: 0.9474
# Epoch 73/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1122 - accuracy: 0.8947
# Epoch 74/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1287 - accuracy: 0.8947
# Epoch 75/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0918 - accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1230 - accuracy: 0.9474
# Epoch 77/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0663 - accuracy: 0.9474
# Epoch 78/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0968 - accuracy: 0.9474
# Epoch 79/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0585 - accuracy: 0.9474
# Epoch 80/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1118 - accuracy: 0.9474
# Epoch 81/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0624 - accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0956 - accuracy: 0.9474
# Epoch 83/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0638 - accuracy: 0.9474
# Epoch 84/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1086 - accuracy: 0.8947
# Epoch 85/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0827 - accuracy: 0.9474
# Epoch 86/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0864 - accuracy: 0.8947
# Epoch 87/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0799 - accuracy: 0.9474
# Epoch 88/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1809 - accuracy: 0.9474
# Epoch 89/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0592 - accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0697 - accuracy: 0.9474
# Epoch 91/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1253 - accuracy: 0.9474
# Epoch 92/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0646 - accuracy: 0.9474
# Epoch 93/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0806 - accuracy: 0.9474
# Epoch 94/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0833 - accuracy: 0.8947
# Epoch 95/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0923 - accuracy: 0.9474
# Epoch 96/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0739 - accuracy: 0.9474
# Epoch 97/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0612 - accuracy: 0.9474
# Epoch 98/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0705 - accuracy: 0.9474
# Epoch 99/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.1017 - accuracy: 0.9474
# Epoch 100/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1159 - accuracy: 0.8947
# Epoch 101/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1124 - accuracy: 0.9474
# Epoch 103/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0717 - accuracy: 0.9474
# Epoch 104/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1294 - accuracy: 0.8947
# Epoch 105/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0634 - accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0797 - accuracy: 0.9474
# Epoch 108/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1596 - accuracy: 0.8947
# Epoch 109/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0622 - accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1113 - accuracy: 0.8947
# Epoch 111/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0720 - accuracy: 0.9474
# Epoch 112/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1213 - accuracy: 0.8947
# Epoch 113/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0454 - accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0861 - accuracy: 0.9474
# Epoch 115/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0407 - accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0934 - accuracy: 0.8947
# Epoch 117/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0978 - accuracy: 0.9474
# Epoch 118/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0753 - accuracy: 0.9474
# Epoch 119/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1518 - accuracy: 0.9474
# Epoch 120/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0932 - accuracy: 0.8947
# Epoch 121/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0417 - accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0778 - accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0894 - accuracy: 0.9474
# Epoch 124/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1163 - accuracy: 0.9474
# Epoch 125/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0423 - accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0849 - accuracy: 0.8947
# Epoch 127/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0441 - accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0855 - accuracy: 0.9474
# Epoch 129/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0646 - accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0669 - accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0452 - accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0868 - accuracy: 0.8947
# Epoch 133/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0613 - accuracy: 0.9474
# Epoch 134/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1158 - accuracy: 0.9474
# Epoch 135/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0591 - accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0717 - accuracy: 0.9474
# Epoch 137/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0828 - accuracy: 0.9474
# Epoch 138/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0817 - accuracy: 0.9474
# Epoch 139/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1743 - accuracy: 0.8947
# Epoch 140/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0456 - accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0710 - accuracy: 0.9474
# Epoch 142/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0843 - accuracy: 0.9474
# Epoch 143/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1081 - accuracy: 0.8947
# Epoch 144/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0432 - accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0963 - accuracy: 0.9474
# Epoch 146/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1046 - accuracy: 0.8947
# Epoch 147/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0334 - accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0877 - accuracy: 0.9474
# Epoch 149/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0892 - accuracy: 0.9474
# Epoch 150/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0810 - accuracy: 0.9474
# Epoch 151/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0692 - accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0843 - accuracy: 0.9474
# Epoch 153/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1376 - accuracy: 0.8947
# Epoch 154/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0444 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0730 - accuracy: 0.9474
# Epoch 157/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1090 - accuracy: 0.8947
# Epoch 158/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1538 - accuracy: 0.8947
# Epoch 159/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0690 - accuracy: 0.9474
# Epoch 160/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0719 - accuracy: 0.9474
# Epoch 161/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0693 - accuracy: 0.9474
# Epoch 162/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0498 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0521 - accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0840 - accuracy: 0.9474
# Epoch 165/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0506 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0672 - accuracy: 0.9474
# Epoch 167/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0613 - accuracy: 0.9474
# Epoch 168/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0538 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0523 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0706 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1166 - accuracy: 0.8947
# Epoch 172/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1049 - accuracy: 0.9474
# Epoch 173/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0316 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0745 - accuracy: 0.9474
# Epoch 175/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1255 - accuracy: 0.8947
# Epoch 176/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0708 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0877 - accuracy: 0.8947
# Epoch 178/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1546 - accuracy: 0.8947
# Epoch 180/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0786 - accuracy: 0.9474
# Epoch 181/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0625 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0661 - accuracy: 0.9474
# Epoch 183/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1057 - accuracy: 0.9474
# Epoch 184/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1009 - accuracy: 0.9474
# Epoch 185/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0753 - accuracy: 0.9474
# Epoch 186/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0509 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0580 - accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0850 - accuracy: 0.9474
# Epoch 189/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0573 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0717 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0591 - accuracy: 0.9474
# Epoch 192/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0304 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1067 - accuracy: 0.8947
# Epoch 194/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0983 - accuracy: 0.9474
# Epoch 195/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1540 - accuracy: 0.8947
# Epoch 196/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0615 - accuracy: 0.9474
# Epoch 197/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0715 - accuracy: 0.9474
# Epoch 198/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0864 - accuracy: 0.9474
# Epoch 199/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0379 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0634 - accuracy: 0.9474

# %% [markdown]
# Creation of the chatbot application:
#
# Great! We've trained our Deep Learning model, but now we need to create the actual functions that would allow us to use our model in a chatbot application. For this next task, I created a set of utility functions that will allow us to easily perform this task.

# %%
def clean_text(text): 
  tokens = nltk.word_tokenize(text)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens
def bag_of_words(text, vocab): 
  tokens = clean_text(text)
  bow = [0] * len(vocab)
  for w in tokens: 
    for idx, word in enumerate(vocab):
      if word == w: 
        bow[idx] = 1
  return np.array(bow)
def pred_class(text, vocab, labels): 
  bow = bag_of_words(text, vocab)
  result = model.predict(np.array([bow]))[0]
  thresh = 0.2
  y_pred = [[idx, res] for idx, res in enumerate(result) if res > thresh]
  y_pred.sort(key=lambda x: x[1], reverse=True)
  return_list = []
  for r in y_pred:
    return_list.append(labels[r[0]])
  return return_list
def get_response(intents_list, intents_json): 
  tag = intents_list[0]
  list_of_intents = intents_json["intents"]
  for i in list_of_intents: 
    if i["tag"] == tag:
      result = random.choice(i["responses"])
      break
  return result

# %% [markdown]
# The next part is simple. We need to create a while loop that allows the user to enter a query which is then cleaned up, i.e. we take the tokens and lemmatize each word. After that, we convert our text into numeric values using our "bag of words" model and make a prediction of which tag the features best represent based on our intentions.
# From there, we take a random answer from our answers in this intent tag and use it to answer the user's query/question.

# %%
# launch of the chatbot
while True:
    message = input("")
    intents = pred_class(message, words, classes)
    result = get_response(intents, data)
    print(result)
# Out:
# 1/1 [==============================] - 0s 67ms/step
# Comment vas tu?
# 1/1 [==============================] - 0s 20ms/step
# Salut à toi!
# 1/1 [==============================] - 0s 24ms/step
# Mon prénom est Miki
# 1/1 [==============================] - 0s 25ms/step
# Hello
# 1/1 [==============================] - 0s 23ms/step
# Salut à toi!
# 1/1 [==============================] - 0s 26ms/step
# Salutations!
# 1/1 [==============================] - 0s 25ms/step
# Comment vas tu?
# 1/1 [==============================] - 0s 15ms/step
# Salut à toi!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/hakim/Documents/Python/chatbot/chatbot.ipynb Cell 20' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/hakim/Documents/Python/chatbot/chatbot.ipynb#ch0000021?line=0'>1</a> # lancement du chatbot
#       <a href='vscode-notebook-cell:/home/hakim/Documents/Python/chatbot/chatbot.ipynb#ch0000021?line=1'>2</a> while True:
# ----> <a href='vscode-notebook-cell:/home/hakim/Documents/Python/chatbot/chatbot.ipynb#ch0000021?line=2'>3</a>     message = input("")
#       <a href='vscode-notebook-cell:/home/hakim/Documents/Python/chatbot/chatbot.ipynb#ch0000021?line=3'>4</a>     intents = pred_class(message, words, classes)
#       <a href='vscode-notebook-cell:/home/hakim/Documents/Python/chatbot/chatbot.ipynb#ch0000021?line=4'>5</a>     result = get_response(intents, data)
#
# File /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py:1165, in Kernel.raw_input(self, prompt)
#    1161 if not self._allow_stdin:
#    1162     raise StdinNotImplementedError(
#    1163         "raw_input was called, but this frontend does not support input requests."
#    1164     )
# -> 1165 return self._input_request(
#    1166     str(prompt),
#    1167     self._parent_ident["shell"],
#    1168     self.get_parent("shell"),
#    1169     password=False,
#    1170 )
#
# File /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py:1207, in Kernel._input_request(self, prompt, ident, parent, password)
#    1204             break
#    1205 except KeyboardInterrupt:
#    1206     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1207     raise KeyboardInterrupt("Interrupted by user") from None
#    1208 except Exception:
#    1209     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
